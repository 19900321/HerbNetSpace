# %%
from generate_embeddings import save_embedding_files, _sample_edge_paths
path_save = 'T3N1W1'
networkf='/home/yin/DREAMwalk-main/DREAMwalk-main/demo/new_2023_11_3_jiaqi/stitch_herbpro_cutoff/DREAMwalk_file.txt'
simf='/home/yin/DREAMwalk-main/DREAMwalk-main/demo/new_2023_11_3_jiaqi/stitch_herbpro_cutoff/total_similarity_aimed.txt'
nodetypef='/home/yin/DREAMwalk-main/DREAMwalk-main/demo/new_2023_11_3_jiaqi/stitch_herbpro_cutoff/node_type.txt'

# node type file should be given for application of heterogeneous Skip-gram
# embeddingf='/home/yin/DREAMwalk-main/DREAMwalk-main/data/data_jiaqi_stitch_cutoff_merge/{}/embedding_file_yin.pkl'.format(path_save)# change
# transmatrixf = '/home/yin/DREAMwalk-main/DREAMwalk-main/data/data_jiaqi_stitch_cutoff_merge/{}/trans_matrix.pkl'.format(path_save)
# walk_pathf = '/home/yin/DREAMwalk-main/DREAMwalk-main/data/data_jiaqi_stitch_cutoff_merge/{}/tmp_walk_file.pkl'.format(path_save) #不变

embeddingf = '/home/yin/DREAMwalk-main/DREAMwalk-main/demo/T3N1W1_embedding_file_LR.pkl'
transmatrixf = '/home/yin/DREAMwalk-main/DREAMwalk-main/demo/T3N1W1_trans_matrix_LR.pkl'
walk_pathf = '/home/yin/DREAMwalk-main/DREAMwalk-main/demo/T3N1W1_tmp_walk_file_LR.pkl'
# node type file should be given for application of heterogeneous Skip-gram


import os
# os.chdir('/home/yin/DREAMwalk-main/DREAMwalk-main/')
embedding_demo = save_embedding_files(netf=networkf,sim_netf=simf, outputf=embeddingf,transmatrixf=transmatrixf,
                         walk_pathf=walk_pathf,nodetypef=nodetypef,tp_factor=0.7,walk_length=5,num_walks=50)
